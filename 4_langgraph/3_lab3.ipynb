# %% [markdown]
# ## Welcome to Week 4, Day 4
#
# This is the start of an AWESOME project! Really simple and very effective.

# %%
from typing import Annotated
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START
from langgraph.graph.message import add_messages
from dotenv import load_dotenv
from IPython.display import Image, display
import gradio as gr
from langgraph.prebuilt import ToolNode, tools_condition
import requests
import os
from langchain_core.tools import Tool

from langchain_openai import ChatOpenAI
from langgraph.checkpoint.memory import MemorySaver

# %%
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Asynchronous LangGraph
#
# To run a tool:
# Sync: `tool.run(inputs)`
# Async: `await tool.arun(inputs)`
#
# To invoke the graph:
# Sync: `graph.invoke(state)`
# Async: `await graph.ainvoke(state)`

# %%
class State(TypedDict):
    
    messages: Annotated[list, add_messages]


graph_builder = StateGraph(State)

# %%
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_user = os.getenv("PUSHOVER_USER")
pushover_url = "https://api.pushover.net/1/messages.json"

def push(text: str):
    """Send a push notification to the user"""
    requests.post(pushover_url, data = {"token": pushover_token, "user": pushover_user, "message": text})

tool_push = Tool(
        name="send_push_notification",
        func=push,
        description="useful for when you want to send a push notification"
    )

# %% [markdown]
# ## Extra installation step - if you don't have Node and Playwright on your computer
#
# Next, you need to install NodeJS and Playwright on your computer if you don't already have them. Please see instructions here:
#
# [Node and Playwright setup](../setup/SETUP-node.md)

# %%
# !node --version
# !npx --version

# %% [markdown]
# ## And now - after Installing Playwright, a heads up for Windows PC Users:
#
# While executing the next few cells, you might hit a problem with the Playwright browser raising a NotImplementedError.
#
# This should work when we move to python modules, but it can cause problems in Windows in a notebook.
#
# If you it this error and would like to run the notebook, you need to make a small change which seems quite hacky! You need to do this AFTER installing Playwright (prior cells)
#
# 1. Right click in `.venv` in the File Explorer on the left and select "Find in folder"
# 2. Search for `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())`
# 3. That code should be found in a line of code in a file called `kernelapp.py`
# 4. Comment out the entire else clause that this line is a part of - see the fragment below. Be sure to have the "pass" statement after the ImportError line.
# 5. Restart the kernel by pressing the "Restart" button above
#
# ```python
#         if sys.platform.startswith("win") and sys.version_info >= (3, 8):
#             import asyncio
#
#             try:
#                 from asyncio import WindowsProactorEventLoopPolicy, WindowsSelectorEventLoopPolicy
#             except ImportError:
#                 pass
#                 # not affected
#            # else:
#             #    if type(asyncio.get_event_loop_policy()) is WindowsProactorEventLoopPolicy:
#                     # WindowsProactorEventLoopPolicy is not compatible with tornado 6
#                     # fallback to the pre-3.8 default of Selector
#                     # asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())
# ```
#
# Thank you to student Nicolas for finding this, and to Kalyan, Yaki, Zibin and Bhaskar for confirming that this worked for them! And to Vladislav for the extra pointers.
#
# As an alternative, you can just move to a Python module (which we do anyway in Day 5)

# %%
# Introducing nest_asyncio
# Python async code only allows for one "event loop" processing aynchronous events.
# The `nest_asyncio` library patches this, and is used for special situations, if you need to run a nested event loop.

import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ### The LangChain community
#
# One of the remarkable things about LangChain is the rich community around it.
#
# Check this out:

# %%
from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
from langchain_community.tools.playwright.utils import create_async_playwright_browser

# If you get a NotImplementedError here or later, see the Heads Up at the top of the notebook

async_browser =  create_async_playwright_browser(headless=False)  # headful mode
toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
tools = toolkit.get_tools()

# %%
for tool in tools:
    print(f"{tool.name}={tool}")
# Out:
# click_element=async_browser=<Browser type=<BrowserType name=chromium executable_path=/root/.cache/ms-playwright/chromium-1200/chrome-linux64/chrome> version=143.0.7499.4>
# navigate_browser=async_browser=<Browser type=<BrowserType name=chromium executable_path=/root/.cache/ms-playwright/chromium-1200/chrome-linux64/chrome> version=143.0.7499.4>
# previous_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=/root/.cache/ms-playwright/chromium-1200/chrome-linux64/chrome> version=143.0.7499.4>
# extract_text=async_browser=<Browser type=<BrowserType name=chromium executable_path=/root/.cache/ms-playwright/chromium-1200/chrome-linux64/chrome> version=143.0.7499.4>
# extract_hyperlinks=async_browser=<Browser type=<BrowserType name=chromium executable_path=/root/.cache/ms-playwright/chromium-1200/chrome-linux64/chrome> version=143.0.7499.4>
# get_elements=async_browser=<Browser type=<BrowserType name=chromium executable_path=/root/.cache/ms-playwright/chromium-1200/chrome-linux64/chrome> version=143.0.7499.4>
# current_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=/root/.cache/ms-playwright/chromium-1200/chrome-linux64/chrome> version=143.0.7499.4>

# %%
tool_dict = {tool.name:tool for tool in tools}

navigate_tool = tool_dict.get("navigate_browser")
extract_text_tool = tool_dict.get("extract_text")

    
await navigate_tool.arun({
    "url": "https://www.cnn.com",
    "timeout": 120000  # 2 minutes
})
text = await extract_text_tool.arun({})
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[14], line 7
#       3 navigate_tool = tool_dict.get("navigate_browser")
#       4 extract_text_tool = tool_dict.get("extract_text")
# ----> 7 await navigate_tool.arun({
#       8     "url": "https://www.cnn.com",
#       9     "timeout": 120000  # 2 minutes
#      10 })
#      11 text = await extract_text_tool.arun({})
#
# File /home/my_projects/wsl_env/lib/python3.10/site-packages/langchain_core/tools/base.py:1117, in BaseTool.arun(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#    1115 if error_to_raise:
#    1116     await run_manager.on_tool_error(error_to_raise)
# -> 1117     raise error_to_raise
#    1119 output = _format_output(content, artifact, tool_call_id, self.name, status)
#    1120 await run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File /home/my_projects/wsl_env/lib/python3.10/site-packages/langchain_core/tools/base.py:1083, in BaseTool.arun(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#    1080         tool_kwargs[config_param] = config
#    1082     coro = self._arun(*tool_args, **tool_kwargs)
# -> 1083     response = await coro_with_context(coro, context)
#    1084 if self.response_format == "content_and_artifact":
#    1085     msg = (
#    1086         "Since response_format='content_and_artifact' "
#    1087         "a two-tuple of the message content and raw tool output is "
#    1088         f"expected. Instead, generated response is of type: "
#    1089         f"{type(response)}."
#    1090     )
#
# File /home/my_projects/wsl_env/lib/python3.10/site-packages/langchain_community/tools/playwright/navigate.py:81, in NavigateTool._arun(self, url, run_manager)
#      79     raise ValueError(f"Asynchronous browser not provided to {self.name}")
#      80 page = await aget_current_page(self.async_browser)
# ---> 81 response = await page.goto(url)
#      82 status = response.status if response else "unknown"
#      83 return f"Navigating to {url} returned status code {status}"
#
# File /home/my_projects/wsl_env/lib/python3.10/site-packages/playwright/async_api/_generated.py:9041, in Page.goto(self, url, timeout, wait_until, referer)
#    8980 async def goto(
#    8981     self,
#    8982     url: str,
#    (...)
#    8988     referer: typing.Optional[str] = None,
#    8989 ) -> typing.Optional["Response"]:
#    8990     """Page.goto
#    8991
#    8992     Returns the main resource response. In case of multiple redirects, the navigation will resolve with the first
#    (...)
#    9037     Union[Response, None]
#    9038     """
#    9040     return mapping.from_impl_nullable(
# -> 9041         await self._impl_obj.goto(
#    9042             url=url, timeout=timeout, waitUntil=wait_until, referer=referer
#    9043         )
#    9044     )
#
# File /home/my_projects/wsl_env/lib/python3.10/site-packages/playwright/_impl/_page.py:552, in Page.goto(self, url, timeout, waitUntil, referer)
#     545 async def goto(
#     546     self,
#     547     url: str,
#    (...)
#     550     referer: str = None,
#     551 ) -> Optional[Response]:
# --> 552     return await self._main_frame.goto(**locals_to_params(locals()))
#
# File /home/my_projects/wsl_env/lib/python3.10/site-packages/playwright/_impl/_frame.py:153, in Frame.goto(self, url, timeout, waitUntil, referer)
#     143 async def goto(
#     144     self,
#     145     url: str,
#    (...)
#     148     referer: str = None,
#     149 ) -> Optional[Response]:
#     150     return cast(
#     151         Optional[Response],
#     152         from_nullable_channel(
# --> 153             await self._channel.send(
#     154                 "goto", self._navigation_timeout, locals_to_params(locals())
#     155             )
#     156         ),
#     157     )
#
# File /home/my_projects/wsl_env/lib/python3.10/site-packages/playwright/_impl/_connection.py:69, in Channel.send(self, method, timeout_calculator, params, is_internal, title)
#      61 async def send(
#      62     self,
#      63     method: str,
#    (...)
#      67     title: str = None,
#      68 ) -> Any:
# ---> 69     return await self._connection.wrap_api_call(
#      70         lambda: self._inner_send(method, timeout_calculator, params, False),
#      71         is_internal,
#      72         title,
#      73     )
#
# File /home/my_projects/wsl_env/lib/python3.10/site-packages/playwright/_impl/_connection.py:559, in Connection.wrap_api_call(self, cb, is_internal, title)
#     557     return await cb()
#     558 except Exception as error:
# --> 559     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     560 finally:
#     561     self._api_zone.set(None)
#
# TimeoutError: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://www.cnn.com/", waiting until "load"

# %%
import textwrap
print(textwrap.fill(text))
# Out:
# Breaking News, Latest News and Videos | CNN CNN values your feedback
# 1. How relevant is this ad to you? 2. Did you encounter any technical
# issues? No Video player was slow to load content Video content never
# loaded Ad froze or did not finish loading Video content did not start
# after ad Audio on ad was too loud Other issues Ad never loaded Ad
# prevented/slowed the page from loading Content moved around while ad
# loaded Ad was repetitive to ads I've seen previously Other issues
# Cancel Submit Thank You! Your effort and contribution in providing
# this feedback is much
# appreciated. Close Ad Feedback Close icon US World Politics Business
# Health Entertainment Style Travel Sports Science Climate Weather
# Winter Olympics 2026 Ukraine-Russia War Israel-Hamas War Games More US
# World Politics Business Health Entertainment Style Travel Sports
# Science Climate Weather Winter Olympics 2026 Ukraine-Russia War
# Israel-Hamas War Games Watch Listen Live TV Subscribe Sign in My
# Account Settings Newsletters Topics you follow Sign out Your CNN
# account Sign in to your CNN account Sign in My Account Settings
# Newsletters Topics you follow Sign out Your CNN account Sign in to
# your CNN account Live TV Listen Watch Edition US International Arabic
# Español Edition US International Arabic Español World Africa Americas
# Asia Australia China Europe India Middle East United Kingdom US
# Politics Trump Facts First CNN Polls 2025 Elections Redistricting
# Tracker Business Tech Media Calculators Videos Markets Pre-markets
# After-Hours Fear & Greed Investing Markets Now Nightcap Health Life,
# But Better Fitness Food Sleep Mindfulness Relationships Entertainment
# Movies Television Celebrity Tech Innovate Foreseeable Future Mission:
# Ahead Work Transformed Innovative Cities Style Arts Design Fashion
# Architecture Luxury Beauty Video Travel Destinations Food & Drink Stay
# News Videos Sports Football Tennis Golf Motorsport US Sports Olympics
# Climbing Esports Hockey Science Space Life Unearthed Climate Solutions
# Weather Weather Video Climate Winter Olympics 2026 Ukraine-Russia War
# Israel-Hamas War Features As Equals Call to Earth Freedom Project
# Impact Your World Inside Africa CNN Heroes Watch Live TV Featured CNN
# Fast Shows A-Z CNN10 CNN TV Schedules Listen CNN 5 Things Chasing Life
# with Dr. Sanjay Gupta The Assignment with Audie Cornish One Thing Tug
# of War CNN Political Briefing The Axe Files All There Is with Anderson
# Cooper All CNN Audio podcasts Games Daily Crossword Jumble Crossword
# Photo Shuffle Sudoblock Sudoku 5 Things Quiz About CNN Photos
# Investigations CNN Profiles CNN Leadership CNN Newsletters Work for
# CNN Follow CNN Iran’s deadly protests US winter storm China’s latest
# military purge Australia shark attacks Mont Blanc rescue Beckham
# family drama Alex Honnold • Analysis Analysis Jonathan
# Nackstrand/AFP/Getty Images Analysis Trade an alliance for an island?
# That’s a bad deal Trump praises British troops after drawing outrage
# at comments downplaying NATO’s role in Afghanistan The week the penny
# dropped for Europe • Live Updates Live Updates Imagn Images, AP, Getty
# Images Live Updates Snow piles up and power outages soar: How a
# massive winter storm is impacting the US Video Good Samaritans help
# push vehicles struggling in Texas snow 0:45 Tracking the US winter
# storm in maps and charts Gallery In pictures: Monster winter storm
# slams the US CNN video analysis sheds new light on killing of Alex
# Pretti Show all • Video 3:51 CNN Video What cellphone footage of the
# fatal shooting in Minneapolis shows 3:51 CNN Investigates Videos
# appear to show agent taking gun away from Pretti just before fatal
# shooting Live Updates Border Patrol commander argues Second Amendment
# did not apply to Pretti How Gregory Bovino became the face of Trump’s
# immigration crackdown US Department of Veterans Affairs Alex Pretti
# was an ICU nurse dedicated to helping others, friends and family said
# • Analysis 2:20 OBTAINTED BY CNN Analysis Does video of Alex Pretti’s
# shooting line up with Noem’s description? 2:20 • Analysis Analysis
# Abbie Parr/AP Analysis Things are only getting worse for Trump’s
# immigration messaging Play Subtitles Off Catch up on today's global
# news • Source: CNN Video Catch up on today’s global news CNN Free solo
# climber Alex Honnold conquers one of the world’s tallest buildings
# Philip Fong/AFP/Getty Images Crowds bid farewell to Japan’s last
# pandas before return to China amid souring ties Courtesy Heather
# Buzzell Outraged nail artists are giving ICE the finger
# FreshSplash/E+/Getty Images Protein is so last year. Why fiber is the
# next big thing • Video 1:11 WBAL/CNN Video Simple steps to stay warm
# if your power knocks out 1:11 Ad Feedback More top stories Omar Al-
# Qattaa/AFP/Getty Images Boys collecting firewood in Gaza killed by
# Israeli fire ‘Our children’s brains are not for sale’: Macron says
# France to fast-track social media ban for under-15s ‘We have to keep
# people warm’: The Ukrainian energy workers risking their lives as
# Russia targets critical facilities Trump says he’s skipping the Super
# Bowl: ‘It’s just too far away’ China’s top general under investigation
# in latest military purge Trump threatens new 100% tariffs on Canada
# over China trade deal Italy protests and recalls ambassador to
# Switzerland after New Year’s bar fire suspect released Weekend Reads •
# Analysis Analysis Dominic Gwinn/Middle East Images/AFP/Getty Images •
# Analysis Analysis Analysis Debunking White Christian Nationalism’s
# biggest myth Airphoto Australia/Photodisc/Getty Images She fell in
# love with an untamed island. Its ‘cute’ inhabitants may have killed
# her Jan 23, 2026 Thomas Coex/AFP/Getty Images Melania Trump’s
# multimillion-dollar documentary project faces a key test this week Jan
# 25, 2026 Ad Feedback Venezuela Jim Lo Scalzo/EPA/Bloomberg/Getty
# Images Trump claims secret ‘discombobulator’ weapon was used to help
# capture Maduro Millions of displaced Venezuelans contemplate returning
# home after Maduro’s ouster Ad Feedback Style Copyright Nan Goldin,
# Courtesy the artist and Gagosian 40 years on, why these radical
# snapshots of love and sex still matter Business & Tech Alex Brandon/AP
# Trump’s stock market: Worst first year of a term since George W. Bush
# Andreas Solaro/AFP/Getty Images Pope Leo warns of ‘overly
# affectionate’ AI chatbots Ad Feedback More on ICE • Analysis Analysis
# Abbie Parr/AP Analysis ‘Thank God we have video’: Minnesota’s
# escalating fights over eyewitness footage Yaakov
# Strasberg/@YaakovStras Mother of tear-gassed family faces backlash as
# video raises questions about a comment from before the incident Kevin
# Dietsch/Getty Images/File Senate Democrats threaten partial government
# shutdown over DHS funding after Minnesota shooting Iran latest
# MAHSA/Middle East Images/AFP/Getty Images The night Iran went dark:
# Witness accounts and video reveal violence inflicted during Iran’s
# internet blackout • Video 1:05 Social media Video Iranian spray paints
# message to Trump: ‘Please help’ 1:05 • Video 8:33 CNN Video Son of
# Iran’s former leader calls for US airstrikes to remove Iranian regime
# 8:33 Ad Feedback Crime & Courts Jane Rosenberg/Reuters Alexander bros:
# Another NY jury will soon weigh the fate of men accused of using their
# celebrity and money to assault women Sinaloa Attorney General’s Office
# US-Mexican influencer abducted at gunpoint in viral video found ‘alive
# and well’ in Sinaloa state Celebrities & entertainment Karwai
# Tang/WireImage/Getty Images Beckham-Peltz wedding DJ reveals how that
# ‘inappropriate’ mother-son dance really went down • Video 1:10 Fyütch
# and Aura V Video 8-year-old gets a Grammy nomination 1:10 Sports Ross
# D. Franklin/AP A teenage golfer is taking The American Express field
# by storm after historic second round Tim Heitman/USA TODAY/Reuters
# Steelers reach verbal agreement for Mike McCarthy to become head coach
# Ad Feedback Travel • Video 1:11 CNN Video How to make Din Tai Fung’s
# iconic soup dumplings 1:11 Health & Wellness Colin Price One cookbook
# author ate chocolate cake daily for 6 years. Now she shares her recipe
# Art & style • Video 2:36 nan goldin Video Why these poignant snapshots
# from the 1980s still resonate today 2:36 CNN Shorts • Video 1:06 CNN
# Video Why Louisville’s snowfall fell short 1:06 • Video 0:55 US
# Department of Veterans Affairs Video Watch 2024 video of Alex Pretti
# honoring veteran 0:55 • Video 1:03 WCBS Video Protests erupt across US
# after Alex Pretti shooting 1:03 • Video 1:21 CNN Video What we know
# about Alex Pretti’s fatal shooting 1:21 • Video 1:05 Associated Press
# Video CNN breaks down videos that led up to Pretti’s death 1:05 •
# Video 1:03 WCBS Video Protests erupt across US after Alex Pretti
# shooting 1:03 • Video 1:00 NBC Video ‘SNL’: Elon Musk wins a ‘Trump
# award’ 1:00 • Video 0:37 CNN Video ‘Free Solo’ climber Alex Honnold
# summits Taipei 101 0:37 • Video 2:20 OBTAINTED BY CNN Video Analysis:
# Does video of Alex Pretti’s shooting line up with Noem’s description?
# 2:20 • Video 1:49 CNN Video Witness recounts deadly ICE shooting 1:49
# • Video 1:22 Lee and Godshall-Bennett, LLP Video Detainees hold
# demonstration inside ICE facility where Liam Conejo Ramos is 1:22 •
# Video 0:48 Reddit / u/pecos_chill Video Federal agents in Minneapolis
# fatally shot a man who DHS says was armed 0:48 • Video 1:36 CNN Video
# Minneapolis protester: ‘We cannot allow this to happen again’ 1:36 •
# Video 0:55 KARE Video Minnesota Governor Walz calls on Trump to remove
# ICE agents 0:55 • Video 1:19 WCCO Video Minneapolis Mayor after latest
# shooting: ‘How many more Americans need to die?’ 1:19 • Video 1:09
# Monae Hendrickson Video One sport that may get you into the Olympics
# 1:09 • Video 1:10 Fyütch and Aura V Video 8-year-old gets a Grammy
# nomination 1:10 • Video 1:05 Social media Video Iranian spray paints
# message to Trump: ‘Please help’ 1:05 • Video 2:19 cnn Video Organizer
# of anti-ICE protest at church speaks out after arrest 2:19 • Video
# 0:55 KARE Video Demonstrators brave frigid cold for ‘ICE Out’ protest
# 0:55 • Video 0:24 TikTok/@detroitmac1313 Video Car crashes into ticket
# counter at Detroit airport 0:24 • Video 0:27 Threads/@debbie.linyuchun
# Video Alex Honnold’s 101-story skyscraper climb delayed for 24 hours
# 0:27 • Video 1:15 CNN Video Why forecasting snowstorms isn’t an exact
# science. 1:15 • Video 2:30 Index Video 3D imaging examines fatal
# shooting of Renee Good 2:30 • Video 1:22 CNN Video US murder rates
# lowest in over a century 1:22 Call to Earth Show all Getty Images He
# brought over 600 water bodies back to life. Now he’s saving India’s
# vanishing stepwells Deshakalyan Chowdhury/AFP/Getty Images Labeled
# ‘husband eaters’ after tiger attacks, these women are finding new
# purpose Northcrest Developments Inside the abandoned airport being
# transformed into a $30 billion sustainable city One Ocean Foundation
# First mission to bottom of deep-sea canyon reveals risks to wildlife
# Ad Feedback More from CNN Natalia V. Osipova Everyone’s trying to feel
# good about wearing fur Unsealed court documents suggest Trump admin
# detained Tufts student for writing op-ed critical of Israel ‘Heated
# Rivalry’ stars named as Winter Olympics torchbearers Trump
# administration is expanding ‘Mexico City’ abortion policy to also ban
# funding for NGOs that it says promote DEI Washington Spirit sign
# soccer star Trinity Rodman to reportedly record three-year contract
# New-wave reactors are the face of an American nuclear renaissance.
# Some experts are sounding alarms After decades of fighting the Iranian
# regime, Kurds see victory edging closer Subscribe Sign in My Account
# Settings Newsletters Topics you follow Sign out Your CNN account Sign
# in to your CNN account Live TV Listen Watch World Africa Americas Asia
# Australia China Europe India Middle East United Kingdom US Politics
# Trump Facts First CNN Polls 2025 Elections Redistricting Tracker
# Business Tech Media Calculators Videos Markets Pre-markets After-Hours
# Fear & Greed Investing Markets Now Nightcap Health Life, But Better
# Fitness Food Sleep Mindfulness Relationships Entertainment Movies
# Television Celebrity Tech Innovate Foreseeable Future Mission: Ahead
# Work Transformed Innovative Cities Style Arts Design Fashion
# Architecture Luxury Beauty Video Travel Destinations Food & Drink Stay
# News Videos Sports Football Tennis Golf Motorsport US Sports Olympics
# Climbing Esports Hockey Science Space Life Unearthed Climate Solutions
# Weather Weather Video Climate Winter Olympics 2026 Ukraine-Russia War
# Israel-Hamas War Features As Equals Call to Earth Freedom Project
# Impact Your World Inside Africa CNN Heroes Watch Live TV Featured CNN
# Headlines Shows A-Z CNN10 CNN TV Schedules Listen CNN 5 Things Chasing
# Life with Dr. Sanjay Gupta The Assignment with Audie Cornish One Thing
# Tug of War CNN Political Briefing The Axe Files All There Is with
# Anderson Cooper All CNN Audio podcasts Games Daily Crossword Jumble
# Crossword Photo Shuffle Sudoblock Sudoku 5 Things Quiz About CNN
# Photos Investigations CNN Profiles CNN Leadership CNN Newsletters Work
# for CNN Watch Listen Live TV Subscribe Sign in My Account Settings
# Newsletters Topics you follow Sign out Your CNN account Sign in to
# your CNN account Follow CNN Download the CNN app Download the CNN app
# Terms of Use Privacy Policy Manage Cookies Ad Choices Accessibility &
# CC About Newsletters Transcripts © 2026 Cable News Network. A Warner
# Bros. Discovery Company. All Rights Reserved. CNN Sans ™ & © 2016
# Cable News Network. Download the CNN app Scan the QR code to download
# the CNN app on Google Play. Download the CNN app Scan the QR code to
# download the CNN app from the Apple Store. Privacy Policy For privacy
# options, please see our privacy policy: https://www.cnn.com/privacy .
# Back Button Cookie List Search Icon Filter Icon Clear checkbox label
# label Apply Cancel Consent Leg.Interest checkbox label label checkbox
# label label checkbox label label Close

# %%
all_tools = tools + [tool_push]

# %%
llm = ChatOpenAI(model="gpt-4o-mini")
llm_with_tools = llm.bind_tools(all_tools)


def chatbot(state: State):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

# %%
graph_builder = StateGraph(State)
graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=all_tools))
graph_builder.add_conditional_edges( "chatbot", tools_condition, "tools")
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

memory = MemorySaver()
graph = graph_builder.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
import gradio as gr
print(gr.__version__)
# Out:
# 6.4.0

# %%
config = {"configurable": {"thread_id": "10"}}

async def chat(user_input: str, history):
    result = await graph.ainvoke({"messages": [{"role": "user", "content": user_input}]}, config=config)
    return result["messages"][-1].content


gr.ChatInterface(fn = chat).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7869
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7869/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/gradio/queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/gradio/route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/gradio/blocks.py", line 2152, in process_api
#     result = await self.call_function(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/gradio/blocks.py", line 1627, in call_function
#     prediction = await fn(*processed_input)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/gradio/utils.py", line 1003, in async_wrapper
#     response = await f(*args, **kwargs)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/gradio/chat_interface.py", line 544, in __wrapper
#     return await submit_fn(*args, **kwargs)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/gradio/chat_interface.py", line 903, in _submit_fn
#     response = await self.fn(*inputs)
#   File "/tmp/ipykernel_61431/2573380078.py", line 4, in chat
#     result = await graph.ainvoke({"messages": [{"role": "user", "content": user_input}]}, config=config)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/pregel/main.py", line 3161, in ainvoke
#     async for chunk in self.astream(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/pregel/main.py", line 2974, in astream
#     async for _ in runner.atick(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/pregel/_runner.py", line 304, in atick
#     await arun_with_retry(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/pregel/_retry.py", line 138, in arun_with_retry
#     return await task.proc.ainvoke(task.input, config)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/_internal/_runnable.py", line 709, in ainvoke
#     input = await step.ainvoke(input, config, **kwargs)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/_internal/_runnable.py", line 473, in ainvoke
#     ret = await self.afunc(*args, **kwargs)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/prebuilt/tool_node.py", line 846, in _afunc
#     outputs = await asyncio.gather(*coros)
#   File "/usr/lib/python3.10/asyncio/tasks.py", line 304, in __wakeup
#     future.result()
#   File "/usr/lib/python3.10/asyncio/tasks.py", line 232, in __step
#     result = coro.send(None)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/prebuilt/tool_node.py", line 1177, in _arun_one
#     return await self._execute_tool_async(tool_request, input_type, config)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/prebuilt/tool_node.py", line 1126, in _execute_tool_async
#     content = _handle_tool_error(e, flag=self._handle_tool_errors)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/prebuilt/tool_node.py", line 430, in _handle_tool_error
#     content = flag(e)  # type: ignore [assignment, call-arg]
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/prebuilt/tool_node.py", line 387, in _default_handle_tool_errors
#     raise e
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/prebuilt/tool_node.py", line 1083, in _execute_tool_async
#     response = await tool.ainvoke(call_args, config)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langchain_core/tools/base.py", line 642, in ainvoke
#     return await self.arun(tool_input, **kwargs)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langchain_core/tools/base.py", line 1117, in arun
#     raise error_to_raise
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langchain_core/tools/base.py", line 1083, in arun
#     response = await coro_with_context(coro, context)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langchain_community/tools/playwright/navigate.py", line 81, in _arun
#     response = await page.goto(url)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/playwright/async_api/_generated.py", line 9041, in goto
#     await self._impl_obj.goto(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/playwright/_impl/_page.py", line 552, in goto
#     return await self._main_frame.goto(**locals_to_params(locals()))
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/playwright/_impl/_frame.py", line 153, in goto
#     await self._channel.send(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/playwright/_impl/_connection.py", line 69, in send
#     return await self._connection.wrap_api_call(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/playwright/_impl/_connection.py", line 559, in wrap_api_call
#     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
# ValueError: Page.goto: The future belongs to a different loop than the one specified as the loop argument

# %%
import gradio as gr

# Example async wrapper
async def chat_fn(user_input):
    result = await graph.ainvoke(
        {"messages": [{"role": "user", "content": user_input}]}, 
        config=config
    )
    return result["messages"][-1].content

# Gradio Blocks UI
with gr.Blocks() as demo:
    chatbot = gr.Chatbot()  # new Chatbot component
    msg = gr.Textbox(label="Enter your message")
    send_btn = gr.Button("Send")

    # Define interaction
    msg.submit(chat_fn, inputs=msg, outputs=chatbot)
    send_btn.click(chat_fn, inputs=msg, outputs=chatbot)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/gradio/queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/gradio/route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/gradio/blocks.py", line 2152, in process_api
#     result = await self.call_function(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/gradio/blocks.py", line 1627, in call_function
#     prediction = await fn(*processed_input)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/gradio/utils.py", line 1003, in async_wrapper
#     response = await f(*args, **kwargs)
#   File "/tmp/ipykernel_61431/227347846.py", line 5, in chat_fn
#     result = await graph.ainvoke(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/pregel/main.py", line 3161, in ainvoke
#     async for chunk in self.astream(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/pregel/main.py", line 2974, in astream
#     async for _ in runner.atick(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/pregel/_runner.py", line 304, in atick
#     await arun_with_retry(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/pregel/_retry.py", line 138, in arun_with_retry
#     return await task.proc.ainvoke(task.input, config)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/_internal/_runnable.py", line 709, in ainvoke
#     input = await step.ainvoke(input, config, **kwargs)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langgraph/_internal/_runnable.py", line 473, in ainvoke
#     ret = await self.afunc(*args, **kwargs)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langchain_core/runnables/config.py", line 610, in run_in_executor
#     return await asyncio.get_running_loop().run_in_executor(
#   File "/usr/lib/python3.10/asyncio/futures.py", line 285, in __await__
#     yield self  # This tells Task to wait for completion.
#   File "/usr/lib/python3.10/asyncio/tasks.py", line 304, in __wakeup
#     future.result()
#   File "/usr/lib/python3.10/asyncio/futures.py", line 201, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "/usr/lib/python3.10/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langchain_core/runnables/config.py", line 601, in wrapper
#     return func(*args, **kwargs)
#   File "/tmp/ipykernel_61431/4196892508.py", line 6, in chatbot
#     return {"messages": [llm_with_tools.invoke(state["messages"])]}
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langchain_core/runnables/base.py", line 5557, in invoke
#     return self.bound.invoke(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py", line 402, in invoke
#     self.generate_prompt(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py", line 1121, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py", line 931, in generate
#     self._generate_with_cache(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py", line 1233, in _generate_with_cache
#     result = self._generate(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langchain_openai/chat_models/base.py", line 1386, in _generate
#     raise e
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/langchain_openai/chat_models/base.py", line 1381, in _generate
#     raw_response = self.client.with_raw_response.create(**payload)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/openai/_legacy_response.py", line 364, in wrapped
#     return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/openai/_utils/_utils.py", line 286, in wrapper
#     return func(*args, **kwargs)
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/openai/resources/chat/completions/completions.py", line 1192, in create
#     return self._post(
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/openai/_base_client.py", line 1259, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#   File "/home/my_projects/wsl_env/lib/python3.10/site-packages/openai/_base_client.py", line 1047, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.BadRequestError: Error code: 400 - {'error': {'message': "An assistant message with 'tool_calls' must be followed by tool messages responding to each 'tool_call_id'. The following tool_call_ids did not have response messages: call_SSFcoxPl7zpY0p0wEwLHCXAW", 'type': 'invalid_request_error', 'param': 'messages.[2].role', 'code': None}}
